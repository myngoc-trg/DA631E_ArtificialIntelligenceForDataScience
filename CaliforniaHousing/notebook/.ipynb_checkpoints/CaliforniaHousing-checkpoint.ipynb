# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib
print("Ready")
# Out:
# Ready

# %%
import sys

print(sys.executable)
# Out:
# /Users/mexmex/anaconda3/envs/ai-datascience/bin/python
